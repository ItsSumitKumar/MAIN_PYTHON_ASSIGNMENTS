# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators.
# *
# ‘hello’
# -87.8
# -
# /
# +
# 6
#
# Answer :- values
#             ( 'hello' ; -87.8 ; 6 )
#
#           expression
#             ( * ; - ; / ; + )
#
#
# 2. What is the difference between string and variable?
#
# Answer :- STRING                                                           |         VARIABLE
#     1.   A string is a type of information you would store in variable .   |  A variale is a store of information .
#     2.   String is a class reference data type & used to represent text    |  A variable is used to represent any value .
#         type data .
#
# 3. Describe three different data types
#
# Answer :- 1. Integers - It contains the whole number in the both negative as well as positive form .
#                 such as , X = 5 ; Y = -5
#
#           2. Floats - these are numbers in decimal forms
#                 such as , x = 5.66 ; y = 5.00
#
#           3. Lists - The ordered collection of data with square brackets "[]"
#                 such as , Fruits = [ "apples" , "oranges" ]   also they are mutable
#
# 4. What is an expression made up of? What do all expressions do?
#
# Answer :- An expression is a combination of operators , constants and variables . An expression may consist of one or more operands , and zero or more           operators to produce a value .
#                                           Expressions are representations of value. They are different from statement in the fact that statements do             something while expressions are representation of value. For example any string is also an expressions since it represents the value of               the string as well .
#
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
# Answer :- 1. Epressions can be assigned or use as operands , while statements can only be declared .
#           2. statements create side effects to be useful , while expressions are values or execute to values .
#           3. Statements are whole structure while expressions are the building blocks .
#           4. expressions are unique in meaning while statements are two-sided in execution .
#
# 6. After running the following code, what does the variable bacon contain?  (bacon = 22 ; bacon + 1 )
#
# Answers :- The bacon variable is set to 20. The bacon + 1 expression does not reassign the value in bacon (that would need an assignment statement:              bacon = bacon + 1)
#
# 7. What should the values of the following two terms be? (‘spam’ + ‘spamspam’  ;  ‘spam’* 3 )
#
# Answers :- Both expressions evaluate to the string 'spamspamspam'
#
# 8.  Why is eggs a valid variable name while 100 is invalid?
#
# Answers :- Variable names cannot begin with a number.
#
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# Answers :- The int(), float(), and str() functions will evaluate to the integer, floating-point number, and string versions of the value passed to                them .
#
# 10. Why does this expression cause an error? How can you fix it? ‘I have eaten’ + 99 + ‘burritos.’
#
# Answers :- The expression causes an error because 99 is an integer, and only strings can be concatenated to other strings with the + operator. The                correct way is I have eaten ' + str(99) + ' burritos.'.
